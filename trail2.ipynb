# %% [markdown]
# <a href="https://colab.research.google.com/github/DrVenkataRajeshKumar/CondyleClassification/blob/main/trail2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Loading standard Libraries and project modules

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
# Load modules/models from EVA course
# !rm -rf Modules
# !git clone https://github.com/EVA4-RS-Group/Phase2 -q --quiet
# !mv ./Phase2/Modules ./Modules
# !rm -rf Phase2
#print("Loaded EVA4 Modules")
from Modules import *

# %% [markdown]
# # 2. Load Data & Set Data Loaders

# %%
# Downloading dataset and unziping into proper folder structure
# !rm -rf final_images
# !wget -q https://github.com/DrVenkataRajeshKumar/CondyleClassification/releases/download/data1/final.images.zip
# !unzip -q final.images.zip

# %% [markdown]
# ## 2.1 Calculate mean and standard deviation for the data

# %%
find_mean_standard_deviation("final images/")
# Out:
# Sub-folders: ['class2', 'class3', 'class1', 'class4']
# Mean: [0.43314943 0.43361538 0.43430133]
# Std: [0.17610069 0.17660347 0.17742199]
# Processing completed in 0m 1s

# %% [markdown]
# ## 2.2 Load images in to DataSet and also perform data transforms

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
data = LoadDataset('final images/', tstRatio = 0.3, batch_size = 20)
# Out:
# ['class1', 'class2', 'class3', 'class4']
# 207
# 69
# 53
# 61
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # 3. Visualize a few images
# Let’s visualize a few training images so as to understand the data augmentations.

# %%
data.show_batch(save_as="sample.jpg")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # 4. Training Mobilenet Model - Only last layers
# Modified last layer from 1000 classes to 4 and make only last layer trainable.
# Here, we need to freeze all the network except the final layer. We need to set requires_grad == False to freeze the parameters so that the gradients are not computed in backward().

# %%
import torch.optim as optim
#from torch_lr_finder import LRFinder

model_ft = models.mobilenet_v2(pretrained=True)
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).

for param in model_ft.parameters():
    param.requires_grad = False

# Parameters of newly constructed modules have requires_grad=True by default
model_ft.classifier[1] = nn.Linear(1280, 4)
model_ft = model_ft.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/mobilenet_v2-b0353104.pth" to /root/.cache/torch/hub/checkpoints/mobilenet_v2-b0353104.pth
#   0%|          | 0.00/13.6M [00:00<?, ?B/s]

# %% [markdown]
# Find hyper parameter lr value using LR Finder

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_ft.classifier[1].parameters(), lr=1e-6, weight_decay=0.01,momentum=0.9)
lr_finder = LRFinder(model_ft, optimizer, criterion, device="cuda")
lr_finder.range_test(data.dataloaders['train'], end_lr=10, num_iter=100)
lr_finder.plot(show_lr=0.2) # to inspect the loss-learning rate graph
lr_finder.reset() # to reset the model and optimizer to their initial stat
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/100 [00:00<?, ?it/s]
# Stopping early, the loss has diverged
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
# Observe that all parameters are being optimized
optimizer_ft = optim.SGD(model_ft.classifier[1].parameters(), lr=0.9, momentum=0.09)

scheduler = optim.lr_scheduler.OneCycleLR(optimizer,
                                          max_lr=0.1, 
                                          steps_per_epoch=len(data.dataloaders['train']), #Training folder size/bs 
                                          epochs=25)

# %%
model_res, plotData = train_model(model_ft, data, device, criterion, optimizer_ft, scheduler,
                       num_epochs=25)
# Out:
# Epoch 0/24
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# /usr/local/lib/python3.7/dist-packages/torch/optim/lr_scheduler.py:134: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# train Loss: 77.4792 Acc: 0.3600
# val Loss: 57.9659 Acc: 0.5391
#
# Epoch 1/24
# ----------
# train Loss: 110.9897 Acc: 0.3236
# val Loss: 94.8079 Acc: 0.5391
#
# Epoch 2/24
# ----------
# train Loss: 80.6996 Acc: 0.3782
# val Loss: 70.3000 Acc: 0.5391
#
# Epoch 3/24
# ----------
# train Loss: 79.9175 Acc: 0.4109
# val Loss: 35.5571 Acc: 0.5391
#
# Epoch 4/24
# ----------
# train Loss: 69.4485 Acc: 0.4073
# val Loss: 24.6638 Acc: 0.5217
#
# Epoch 5/24
# ----------
# train Loss: 54.3533 Acc: 0.4218
# val Loss: 41.2781 Acc: 0.4783
#
# Epoch 6/24
# ----------
# train Loss: 67.5022 Acc: 0.3891
# val Loss: 94.5280 Acc: 0.1565
#
# Epoch 7/24
# ----------
# train Loss: 72.2111 Acc: 0.4000
# val Loss: 19.5263 Acc: 0.3739
#
# Epoch 8/24
# ----------
# train Loss: 62.6603 Acc: 0.3745
# val Loss: 38.9720 Acc: 0.5304
#
# Epoch 9/24
# ----------
# train Loss: 66.1549 Acc: 0.3709
# val Loss: 68.2602 Acc: 0.4435
#
# Epoch 10/24
# ----------
# train Loss: 78.0418 Acc: 0.3673
# val Loss: 43.9575 Acc: 0.1478
#
# Epoch 11/24
# ----------
# train Loss: 57.8028 Acc: 0.4291
# val Loss: 37.2787 Acc: 0.5391
#
# Epoch 12/24
# ----------
# train Loss: 65.4861 Acc: 0.3964
# val Loss: 38.5913 Acc: 0.5304
#
# Epoch 13/24
# ----------
# train Loss: 60.2050 Acc: 0.4218
# val Loss: 42.9891 Acc: 0.1826
#
# Epoch 14/24
# ----------
# train Loss: 48.6230 Acc: 0.4364
# val Loss: 39.7968 Acc: 0.4087
#
# Epoch 15/24
# ----------
# train Loss: 53.5323 Acc: 0.4036
# val Loss: 63.0168 Acc: 0.5391
#
# Epoch 16/24
# ----------
# train Loss: 50.0250 Acc: 0.4473
# val Loss: 21.3968 Acc: 0.4348
#
# Epoch 17/24
# ----------
# train Loss: 56.0808 Acc: 0.4509
# val Loss: 33.3734 Acc: 0.1913
#
# Epoch 18/24
# ----------
# train Loss: 49.3639 Acc: 0.4509
# val Loss: 41.9158 Acc: 0.5391
#
# Epoch 19/24
# ----------
# train Loss: 49.9370 Acc: 0.4545
# val Loss: 43.2283 Acc: 0.2087
#
# Epoch 20/24
# ----------
# train Loss: 51.3902 Acc: 0.4582
# val Loss: 27.6748 Acc: 0.5130
#
# Epoch 21/24
# ----------
# train Loss: 43.9713 Acc: 0.4909
# val Loss: 32.0961 Acc: 0.3130
#
# Epoch 22/24
# ----------
# train Loss: 46.3298 Acc: 0.4691
# val Loss: 19.8362 Acc: 0.2348
#
# Epoch 23/24
# ----------
# train Loss: 54.3293 Acc: 0.4327
# val Loss: 31.9896 Acc: 0.5217
#
# Epoch 24/24
# ----------
# train Loss: 41.6227 Acc: 0.5164
# val Loss: 19.3607 Acc: 0.2522
#
# Training complete in 0m 45s
# Best val Acc: 0.539130

# %%
visualize_model(model_res, data, device,"visualize_1.jpg")
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
PlotGraph(plotData,"loss_accuracy_1.jpg")

# %% [markdown]
# #6. Finetuning the Model by Training all layers
# Load a trained model and unfreeze all the layers. Train again to improve the accuracy.

# %%
model_conv = model_res
# Here the size of each output sample is set to 2.
# Alternatively, it can be generalized to nn.Linear(num_ftrs, len(class_names)).

model_conv = model_conv.to(device)

for param in model_conv.parameters():
    param.requires_grad = True

# %%
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(model_conv.parameters(), lr=1e-6, weight_decay=0.01,momentum=0.9)
lr_finder = LRFinder(model_conv, optimizer, criterion, device="cuda")
lr_finder.range_test(data.dataloaders['train'], end_lr=10, num_iter=100)
lr_finder.plot(show_lr=0.01) # to inspect the loss-learning rate graph
lr_finder.reset() # to reset the model and optimizer to their initial stat
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
#   0%|          | 0/100 [00:00<?, ?it/s]
# Learning rate search finished. See the graph with {finder_name}.plot()

# %%
# Observe that only parameters of final layer are being optimized as
# opposed to before.
optimizer_conv = optim.SGD(model_conv.parameters(), lr=0.001, momentum=0.9,nesterov=True, weight_decay=1e-4)

# One Cycle Policy
scheduler = optim.lr_scheduler.OneCycleLR(optimizer_conv,
                                          max_lr=0.01, 
                                          steps_per_epoch=len(data.dataloaders['train']), #Training folder size/bs
                                          epochs=30,pct_start=0.2, div_factor=10, final_div_factor=100)

# %%
model_final, plotData = train_model(model_conv, data, device, criterion, optimizer_conv, scheduler,
                       num_epochs=30)
# Out:
# Epoch 0/29
# ----------
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# train Loss: 100.7459 Acc: 0.5164
# val Loss: 413.3888 Acc: 0.5391
#
# Epoch 1/29
# ----------
# train Loss: 24.5934 Acc: 0.4436
# val Loss: 421.5747 Acc: 0.1565
#
# Epoch 2/29
# ----------
# train Loss: 11.2965 Acc: 0.2982
# val Loss: 41.5939 Acc: 0.1565
#
# Epoch 3/29
# ----------
# train Loss: 2.3961 Acc: 0.4873
# val Loss: 39.8746 Acc: 0.3565
#
# Epoch 4/29
# ----------
# train Loss: 3.1668 Acc: 0.5055
# val Loss: 75.9525 Acc: 0.1913
#
# Epoch 5/29
# ----------
# train Loss: 4.0194 Acc: 0.4691
# val Loss: 22.9303 Acc: 0.2087
#
# Epoch 6/29
# ----------
# train Loss: 6.9380 Acc: 0.4473
# val Loss: 33.3065 Acc: 0.1652
#
# Epoch 7/29
# ----------
# train Loss: 3.7379 Acc: 0.3891
# val Loss: 1.5350 Acc: 0.4696
#
# Epoch 8/29
# ----------
# train Loss: 2.0346 Acc: 0.4255
# val Loss: 13.7076 Acc: 0.3565
#
# Epoch 9/29
# ----------
# train Loss: 1.8545 Acc: 0.4836
# val Loss: 10.3627 Acc: 0.3478
#
# Epoch 10/29
# ----------
# train Loss: 1.9507 Acc: 0.4764
# val Loss: 6.2297 Acc: 0.4783
#
# Epoch 11/29
# ----------
# train Loss: 1.5839 Acc: 0.5091
# val Loss: 4.8271 Acc: 0.5043
#
# Epoch 12/29
# ----------
# train Loss: 1.7320 Acc: 0.5164
# val Loss: 2.8261 Acc: 0.4957
#
# Epoch 13/29
# ----------
# train Loss: 1.6266 Acc: 0.5236
# val Loss: 3.8532 Acc: 0.5130
#
# Epoch 14/29
# ----------
# train Loss: 1.6136 Acc: 0.5127
# val Loss: 4.1203 Acc: 0.5217
#
# Epoch 15/29
# ----------
# train Loss: 1.5674 Acc: 0.5164
# val Loss: 3.6427 Acc: 0.5217
#
# Epoch 16/29
# ----------
# train Loss: 1.3839 Acc: 0.5345
# val Loss: 3.3935 Acc: 0.4783
#
# Epoch 17/29
# ----------
# train Loss: 1.4552 Acc: 0.5236
# val Loss: 3.8408 Acc: 0.4174
#
# Epoch 18/29
# ----------
# train Loss: 1.5913 Acc: 0.5273
# val Loss: 2.4608 Acc: 0.5304
#
# Epoch 19/29
# ----------
# train Loss: 1.3980 Acc: 0.5164
# val Loss: 3.7452 Acc: 0.4609
#
# Epoch 20/29
# ----------
# train Loss: 1.4291 Acc: 0.4945
# val Loss: 4.0298 Acc: 0.4261
#
# Epoch 21/29
# ----------
# train Loss: 1.4402 Acc: 0.5200
# val Loss: 3.2578 Acc: 0.5304
#
# Epoch 22/29
# ----------
# train Loss: 1.2510 Acc: 0.5382
# val Loss: 3.5435 Acc: 0.4087
#
# Epoch 23/29
# ----------
# train Loss: 1.3020 Acc: 0.5382
# val Loss: 3.0713 Acc: 0.4435
#
# Epoch 24/29
# ----------
# train Loss: 1.2766 Acc: 0.5491
# val Loss: 2.7817 Acc: 0.5130
#
# Epoch 25/29
# ----------
# train Loss: 1.3274 Acc: 0.5236
# val Loss: 3.3323 Acc: 0.5217
#
# Epoch 26/29
# ----------
# train Loss: 1.4015 Acc: 0.5273
# val Loss: 3.4716 Acc: 0.5130
#
# Epoch 27/29
# ----------
# train Loss: 1.1928 Acc: 0.5418
# val Loss: 3.5600 Acc: 0.4957
#
# Epoch 28/29
# ----------
# train Loss: 1.3119 Acc: 0.5273
# val Loss: 3.7311 Acc: 0.4870
#
# Epoch 29/29
# ----------
# train Loss: 1.2938 Acc: 0.5309
# val Loss: 3.6977 Acc: 0.4783
#
# Training complete in 1m 15s
# Best val Acc: 0.539130

# %%
visualize_model(model_res, data, device,"visualize_2.jpg")
plt.ioff()
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
PlotGraph(plotData,"loss_accuracy_2.jpg")

# %% [markdown]
# # 7. Plotting Misclassified images

# %%
print("Miss-Classified Images in Class1")
ShowMissclassifiedImages(model_final, data,0, device,save_as="MisclassifiedClass1.jpg")
# Out:
# Miss-Classified Images in Class1
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
print("Miss-Classified Images in Large Quadcopters")
ShowMissclassifiedImages(model_final, data,1, device,save_as="MisclassifiedLargeQuadcopter.jpg")
# Out:
# Miss-Classified Images in Large Quadcopters
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
print("Miss-Classified Images in Small Quadcopters")
ShowMissclassifiedImages(model_final, data,2, device,save_as="MisclassifiedSmallQuadcopter.jpg")
# Out:
# Miss-Classified Images in Small Quadcopters
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %%
print("Miss-Classified Images in Winged Drones")
ShowMissclassifiedImages(model_final, data,3, device,save_as="MisclassifiedWingedDrones.jpg")
# Out:
# Miss-Classified Images in Winged Drones
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# # 8. Saving Model

# %%
# Save GPU Model
torch.save(model_final.state_dict(), '/content/mobilenet_v2_custom_trained_gpu_v6.pt')

# Load CPU Model
device = torch.device('cpu')
model = models.mobilenet_v2(pretrained=False)
model.classifier[1] = nn.Linear(1280, 4)
model.load_state_dict(torch.load('/content/mobilenet_v2_custom_trained_gpu_v6.pt',
                                 map_location=device))

# Saving Trace Model
model.eval()
# trace model with a dummy input
traced_model = torch.jit.trace(model, torch.randn(1, 3, 224, 224))
traced_model.save('mobilenet_v2_custom_trained_v6.pt')
